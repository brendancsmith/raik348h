# %%
# ----- standard modules -----

import sys

from __future__ import division

# ----- libraries -----

from sklearn.linear_model import LogisticRegression
from sklearn import metrics
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
np.set_printoptions(suppress=True)

# %%
custFile1 = 'mcf1.csv'
custFile2 = 'mcf2.csv'

# %%
def munge(sample):
    labelColumn = 'WINETAST'
    idColumn = 'CUSTID'

    # print(sample.columns)

    # get feature/predictor matrix as numpy array
    x = sample.drop(idColumn, axis=1).drop(labelColumn, axis=1)

    x = x.replace('.', np.nan).applymap(np.float64)
    x = x.dropna(axis=1)
    print(x.head())
    # x.fillna(x.mean(), inplace=True)
    # x.fillna(0, inplace=True)
    
    # get labels array
    y = sample[labelColumn]
    
    return x, y


def regress(x, y, **kwargs):
    model = LogisticRegression(**kwargs)
    model.fit(x, y)
    
    return model


def get_coef(model, x, sort=False):
    # examine the coefficients
    values = map(lambda x: x[0], np.transpose(model.coef_))
    coef = pd.DataFrame(list(zip(x.columns, values)))
    
    coef.columns = ['Label', 'Value']
    
    if sort:
        coef = coef.sort_values(by='Value', ascending=False)
    
    return coef

# %%
sample1 = pd.read_csv(custFile1)
sample2 = pd.read_csv(custFile2)
sample = pd.concat([sample1, sample2])

x, y = munge(sample)

class_weight = {0:0.1, 1:0.9}

# model, coef = regress(x, y, class_weight=class_weight)
model = regress(x, y, solver='newton-cg', max_iter=1000, class_weight=class_weight)
# model, coef = regress(x, y, solver='lbfgs', max_iter=1000, class_weight=class_weight)
# Out:
#    AGE  AGEGRP1  AGEGRP2  AGEGRP3  AGEGRP4  AGEGRP5  AGEGRP6  SEX  EDUC  \
# 0   27        0        1        0        0        0        0    0    19
# 1   70        0        0        0        0        0        1    0    18
# 2   31        0        1        0        0        0        0    0    16
# 3   37        0        0        1        0        0        0    0    18
# 4   48        0        0        0        1        0        0    0    15
#
#    INCOME    ...     PERCDR  PERCSR  PERCDW  PERCSW  PERCDE  PERCEX  TOTLCOMP  \
# 0   30649    ...          0       0       0       0     100       0         0
# 1  164417    ...         35      20       0      35      10      25         0
# 2   29648    ...          0      50       0      50       0       0         0
# 3   26188    ...        100       0       0       0       0       0         0
# 4  130141    ...         52      30      11       4       3      12         1
#
#    TOTWCOMP  TOTPCOMM  FACEBOOK
# 0         0         0         0
# 1         0         0         0
# 2         0         0         0
# 3         0         0         0
# 4         0         0         0
#
# [5 rows x 53 columns]

# %%
model.score(x,y)
# Out:
# 0.88849442472123608

# %%
get_coef(model, x, True)
# Out:
#        Label     Value
# 19  WINEMAGS  1.927829
# 18  GOURMAGS  1.039522
# 21  HOUSMAGS  0.519607
# 15   INCGRP6  0.339545
# 20  STYLMAGS  0.271499
# 25  COMPMAGS  0.259702
# 4    AGEGRP4  0.197466
# 2    AGEGRP2  0.195918
# 30    TOTCAT  0.188015
# 44    PERCSR  0.156255
# 47    PERCDE  0.153737
# 45    PERCDW  0.152451
# 43    PERCDR  0.148408
# 46    PERCSW  0.146088
# 5    AGEGRP5  0.066392
# 14   INCGRP5  0.055734
# 28    NPURCH  0.033378
# 39  AVGPURCH  0.028301
# 22  SPRTMAGS  0.024999
# 38  PROBSTAY  0.008448
# 41   AVGQUAL  0.008038
# 36  COSTLAST  0.004536
# 13   INCGRP4  0.004084
# 0        AGE  0.003236
# 33  TOTCPROF  0.003224
# 32  TOTCCOST  0.002211
# 40   AVGDISC  0.001235
# 48    PERCEX  0.000562
# 9     INCOME  0.000005
# 34  REV1STYR -0.000043
# 37       LTV -0.000161
# 27   LASTPUR -0.000668
# 42    PCTWEB -0.000967
# 31   TOTCREV -0.002366
# 26  FIRSTPUR -0.002819
# 35  REVLSTYR -0.003269
# 29  TBOTTLES -0.007992
# 51  TOTPCOMM -0.021591
# 10   INCGRP1 -0.030551
# 52  FACEBOOK -0.035993
# 6    AGEGRP6 -0.096263
# 12   INCGRP3 -0.103478
# 49  TOTLCOMP -0.112735
# 1    AGEGRP1 -0.129338
# 8       EDUC -0.157620
# 50  TOTWCOMP -0.234767
# 3    AGEGRP3 -0.234887
# 11   INCGRP2 -0.266046
# 23  TRAVMAGS -0.326485
# 24  CULTMAGS -0.373072
# 7        SEX -0.399036
# 17  TEENHOME -1.882754
# 16   KIDHOME -3.195132

# %%
#get_coef(model, x, False).to_csv('coef.csv', float_format='{:f}'.format, encoding='utf-8')

# %%
predictedAcceptRate
# Out:
# 0.18085904295214761

# %%
precision
# Out:
# 0.42410837710810062

# %%
def calculate_profit(model, x, y, _custPop=None):
    predicted = model.predict(x)

    predictedAcceptRate = predicted.mean()
    precision = metrics.precision_score(y, predicted)
    
    costPerCall = 3.20
    
    custPop = _custPop if _custPop is not None else 280000
    
    numCalls = predictedAcceptRate * custPop
    totalCallCost = numCalls * costPerCall
    testPromotionCost = 24000
    
    totalCost = totalCallCost + testPromotionCost 
    
    numResponses = precision * numCalls
    profit = 25
    grossProfit = profit * numResponses
    
    netProfit = grossProfit - totalCost
    return netProfit

# %%
calculate_profit(model, x, y)
# Out:
# 350877.14385719283

# %%
def find_best_model(x, y, linParams):
    
    maxProfit = -sys.maxint - 1
    bestModel = None
    
    for i in np.linspace(*linParams):
        class_weight = {0:i, 1:1-i}
        model = regress(x, y, solver='newton-cg', max_iter=1000, class_weight=class_weight)
        profit = calculate_profit(model, x, y)
        
        print(class_weight, profit)
        
        if profit > maxProfit:
            maxProfit = profit
            bestModel = model
        
    return bestModel

# %%
#bestModel = find_best_model(x, y, (0.09, 0.11, 10+1))
#calculate_profit(bestModel, x, y)

# %%
model.get_params()
# Out:
# {'C': 1.0,
#  'class_weight': {0: 0.1, 1: 0.9},
#  'dual': False,
#  'fit_intercept': True,
#  'intercept_scaling': 1,
#  'max_iter': 1000,
#  'multi_class': 'ovr',
#  'penalty': 'l2',
#  'random_state': None,
#  'solver': 'newton-cg',
#  'tol': 0.0001,
#  'verbose': 0}

# %%
predicted = model.predict(x)
predictedAcceptRate = predicted.mean()
precision = metrics.precision_score(y, predicted)

# %%
print(predictedAcceptRate)
print(precision)
# Out:
# 0.180859042952
# 0.424108377108

# %%
x.head(10)
# Out:
#    AGE  AGEGRP1  AGEGRP2  AGEGRP3  AGEGRP4  AGEGRP5  AGEGRP6  SEX  EDUC  \
# 0   27        0        1        0        0        0        0    0    19
# 1   70        0        0        0        0        0        1    0    18
# 2   31        0        1        0        0        0        0    0    16
# 3   37        0        0        1        0        0        0    0    18
# 4   48        0        0        0        1        0        0    0    15
# 5   60        0        0        0        0        1        0    1    17
# 6   67        0        0        0        0        0        1    0    20
# 7   60        0        0        0        0        1        0    0    12
# 8   56        0        0        0        0        1        0    1    20
# 9   74        0        0        0        0        0        1    1    20
#
#    INCOME    ...     PERCDR  PERCSR  PERCDW  PERCSW  PERCDE  PERCEX  TOTLCOMP  \
# 0   30649    ...          0       0       0       0     100       0         0
# 1  164417    ...         35      20       0      35      10      25         0
# 2   29648    ...          0      50       0      50       0       0         0
# 3   26188    ...        100       0       0       0       0       0         0
# 4  130141    ...         52      30      11       4       3      12         1
# 5  149972    ...          0     100       0       0       0       0         0
# 6  107571    ...         59      23       0       9       9       0         0
# 7  131288    ...         52      28      13       5       2      15         0
# 8   75083    ...          0       0       0       0     100       0         0
# 9   83762    ...         33      67       0       0       0       0         0
#
#    TOTWCOMP  TOTPCOMM  FACEBOOK
# 0         0         0         0
# 1         0         0         0
# 2         0         0         0
# 3         0         0         0
# 4         0         0         0
# 5         0         0         0
# 6         0         0         0
# 7         0         0         0
# 8         0         0         0
# 9         0         0         0
#
# [10 rows x 53 columns]

# %%
model.decision_function(x.head(10))
# Out:
# array([-5.43987388, -0.43201208, -5.96429442, -9.81467201,  0.22586001,
#        -1.65126692,  1.94110873,  1.72003775, -5.294323  , -3.03026437])

# %%
model.predict(x.head(10))
# Out:
# array([0, 0, 0, 0, 1, 0, 1, 1, 0, 0])

# %%
model.intercept_
# Out:
# array([-19.47604984])

# %%
def construct_decision_equation(model, x, y):
    eq = '({})'.format(model.intercept_[0])
    
    coefs = get_coef(model, x)
    
    for i in coefs.index:
        eq += ' + ({} * {})'.format(coefs['Value'][i], coefs['Label'][i])
        
    return eq

# %%
construct_decision_equation(model, x, y)
# Out:
# '(-19.4760498402) + (0.00323642809063 * AGE) + (-0.129337782167 * AGEGRP1) + (0.195917525412 * AGEGRP2) + (-0.234886978876 * AGEGRP3) + (0.19746565346 * AGEGRP4) + (0.0663924279262 * AGEGRP5) + (-0.0962625158959 * AGEGRP6) + (-0.399035861315 * SEX) + (-0.157619919721 * EDUC) + (5.17004482356e-06 * INCOME) + (-0.0305505558763 * INCGRP1) + (-0.266046084692 * INCGRP2) + (-0.103478438587 * INCGRP3) + (0.00408439103736 * INCGRP4) + (0.0557339914639 * INCGRP5) + (0.339545026514 * INCGRP6) + (-3.19513244721 * KIDHOME) + (-1.88275438836 * TEENHOME) + (1.03952152631 * GOURMAGS) + (1.92782909236 * WINEMAGS) + (0.271499009826 * STYLMAGS) + (0.519606890683 * HOUSMAGS) + (0.0249994469138 * SPRTMAGS) + (-0.326484625943 * TRAVMAGS) + (-0.37307193912 * CULTMAGS) + (0.259702303498 * COMPMAGS) + (-0.00281925146687 * FIRSTPUR) + (-0.000668390005902 * LASTPUR) + (0.0333776297608 * NPURCH) + (-0.00799168299087 * TBOTTLES) + (0.188014579598 * TOTCAT) + (-0.00236609418628 * TOTCREV) + (0.00221061370842 * TOTCCOST) + (0.00322375512265 * TOTCPROF) + (-4.30347716814e-05 * REV1STYR) + (-0.00326910974595 * REVLSTYR) + (0.00453598514997 * COSTLAST) + (-0.000161131317336 * LTV) + (0.00844750330598 * PROBSTAY) + (0.0283013808274 * AVGPURCH) + (0.00123450630267 * AVGDISC) + (0.00803807273412 * AVGQUAL) + (-0.000966813661525 * PCTWEB) + (0.148407893369 * PERCDR) + (0.156255012784 * PERCSR) + (0.152450538613 * PERCDW) + (0.146088229781 * PERCSW) + (0.153736561834 * PERCDE) + (0.0005617527894 * PERCEX) + (-0.112735474119 * TOTLCOMP) + (-0.234767258281 * TOTWCOMP) + (-0.021591479026 * TOTPCOMM) + (-0.0359927679588 * FACEBOOK)'

# %%
x1, y1 = munge(sample1)
x2, y2 = munge(sample2)

# %%
calculate_profit(model, x1, y1, 10000)
# Out:
# 358779.20160000003

# %%
calculate_profit(model, x2, y2, 10000)
# Out:
# 366324.95409540954

# %%
xDegrouped = x.drop('AGEGRP1', axis=1).drop('AGEGRP2', axis=1).drop('AGEGRP3', axis=1).drop('AGEGRP4', axis=1).drop('AGEGRP5', axis=1).drop('AGEGRP6', axis=1).drop('INCGRP1', axis=1).drop('INCGRP2', axis=1).drop('INCGRP3', axis=1).drop('INCGRP4', axis=1).drop('INCGRP5', axis=1).drop('INCGRP6', axis=1)
corr = xDegrouped.corr()
corr = corr.replace(1, np.nan)
corr
# Out:
#                AGE       SEX      EDUC    INCOME   KIDHOME  TEENHOME  \
# AGE            NaN  0.002619  0.004008  0.710900 -0.646689 -0.219803
# SEX       0.002619       NaN -0.000184  0.001138  0.002303 -0.003635
# EDUC      0.004008 -0.000184       NaN  0.002187  0.007665 -0.005426
# INCOME    0.710900  0.001138  0.002187       NaN -0.479810 -0.155058
# KIDHOME  -0.646689  0.002303  0.007665 -0.479810       NaN  0.150782
# TEENHOME -0.219803 -0.003635 -0.005426 -0.155058  0.150782       NaN
# GOURMAGS  0.410975  0.002184  0.137069  0.506764 -0.342302 -0.217249
# WINEMAGS  0.221585 -0.001291  0.310530  0.264022 -0.203127 -0.122305
# STYLMAGS  0.362207  0.435966 -0.000258  0.481214 -0.276748 -0.155992
# HOUSMAGS  0.267592  0.390781  0.000696  0.332192 -0.235332 -0.155848
# SPRTMAGS  0.179581 -0.252919  0.002855  0.218947 -0.149521 -0.092492
# TRAVMAGS  0.365941 -0.002092  0.282254  0.426142 -0.323109 -0.208223
# CULTMAGS  0.129953 -0.001243  0.477551  0.150100 -0.108910 -0.070651
# COMPMAGS -0.068861 -0.000580  0.212265  0.043459  0.039741  0.011541
# FIRSTPUR  0.000070  0.004308 -0.003044 -0.007065 -0.001322 -0.010750
# LASTPUR  -0.351985 -0.004335 -0.003064 -0.400978  0.321677  0.196560
# NPURCH    0.348549  0.007123 -0.010027  0.441251 -0.288074 -0.181086
# TBOTTLES  0.359974  0.008097 -0.009164  0.486179 -0.281984 -0.181977
# TOTCAT   -0.000430  0.003680 -0.003764 -0.007622 -0.001148 -0.010843
# TOTCREV   0.338035  0.004436 -0.007900  0.465027 -0.263551 -0.169169
# TOTCCOST  0.341328  0.005879 -0.010924  0.462820 -0.267444 -0.171305
# TOTCPROF  0.269283 -0.002391  0.006179  0.398962 -0.204339 -0.132698
# REV1STYR  0.337387  0.004981 -0.007827  0.465195 -0.260242 -0.164561
# REVLSTYR  0.382946  0.006566 -0.003660  0.519545 -0.297715 -0.189856
# COSTLAST  0.385050  0.007736 -0.002374  0.518955 -0.301587 -0.192244
# LTV       0.303245 -0.000347 -0.008215  0.426318 -0.226384 -0.145487
# PROBSTAY  0.249073  0.007544  0.003789  0.275370 -0.227414 -0.149729
# AVGPURCH  0.547741  0.001119 -0.008945  0.689209 -0.440753 -0.278194
# AVGDISC  -0.374628  0.002505  0.005300 -0.436021  0.335492  0.218168
# AVGQUAL   0.329251  0.006218 -0.011070  0.388121 -0.291136 -0.178674
# PCTWEB   -0.119976  0.000960  0.387639  0.078701  0.067428  0.021503
# PERCDR   -0.034101 -0.005965  0.002287 -0.047264  0.037588  0.021599
# PERCSR    0.094689  0.005610 -0.008159  0.110663 -0.088950 -0.050395
# PERCDW    0.088678  0.006305  0.001824  0.106584 -0.073766 -0.058333
# PERCSW   -0.100478 -0.002653  0.003582 -0.115206  0.080994  0.052619
# PERCDE   -0.014312  0.001294  0.001768 -0.007902  0.013125  0.011207
# PERCEX    0.109337  0.006400 -0.006638  0.137107 -0.100116 -0.065858
# TOTLCOMP  0.105599  0.002032  0.106542  0.133814 -0.091494 -0.056391
# TOTWCOMP  0.114501 -0.000674  0.100368  0.142149 -0.087854 -0.056513
# TOTPCOMM  0.041707  0.008251 -0.013074  0.030944 -0.041996 -0.021100
# FACEBOOK -0.115318  0.004810  0.004056 -0.137645  0.110675  0.075065
#
#           GOURMAGS  WINEMAGS  STYLMAGS  HOUSMAGS    ...       PERCDR  \
# AGE       0.410975  0.221585  0.362207  0.267592    ...    -0.034101
# SEX       0.002184 -0.001291  0.435966  0.390781    ...    -0.005965
# EDUC      0.137069  0.310530 -0.000258  0.000696    ...     0.002287
# INCOME    0.506764  0.264022  0.481214  0.332192    ...    -0.047264
# KIDHOME  -0.342302 -0.203127 -0.276748 -0.235332    ...     0.037588
# TEENHOME -0.217249 -0.122305 -0.155992 -0.155848    ...     0.021599
# GOURMAGS       NaN  0.502898  0.283683  0.303636    ...    -0.058934
# WINEMAGS  0.502898       NaN  0.147261  0.156403    ...    -0.073336
# STYLMAGS  0.283683  0.147261       NaN  0.585440    ...    -0.031393
# HOUSMAGS  0.303636  0.156403  0.585440       NaN    ...    -0.031239
# SPRTMAGS  0.272963  0.144591 -0.054835 -0.014043    ...    -0.013379
# TRAVMAGS  0.421141  0.281179  0.224492  0.173494    ...    -0.017682
# CULTMAGS  0.207210  0.361388  0.074956  0.053666    ...     0.004727
# COMPMAGS  0.045541  0.080675  0.005805  0.006149    ...     0.006995
# FIRSTPUR -0.004569  0.006245  0.001816 -0.002567    ...     0.005597
# LASTPUR  -0.286063 -0.216907 -0.206569 -0.165659    ...     0.068966
# NPURCH    0.344354  0.243097  0.244658  0.191550    ...    -0.060592
# TBOTTLES  0.362072  0.225948  0.272602  0.218195    ...    -0.054108
# TOTCAT   -0.005488  0.006688  0.001818 -0.002513    ...     0.005908
# TOTCREV   0.379411  0.249142  0.260894  0.219823    ...    -0.052829
# TOTCCOST  0.362223  0.243255  0.258618  0.207804    ...    -0.052581
# TOTCPROF  0.390637  0.233661  0.228223  0.235053    ...    -0.045313
# REV1STYR  0.375591  0.249563  0.259285  0.220067    ...    -0.044908
# REVLSTYR  0.424895  0.277110  0.293587  0.248953    ...    -0.058384
# COSTLAST  0.407429  0.272557  0.291416  0.235685    ...    -0.057689
# LTV       0.411864  0.242786  0.246439  0.252184    ...    -0.050663
# PROBSTAY  0.197134  0.159964  0.145903  0.111526    ...    -0.041665
# AVGPURCH  0.575566  0.381853  0.382516  0.339468    ...    -0.023563
# AVGDISC  -0.445607 -0.273773 -0.255942 -0.286338    ...    -0.005544
# AVGQUAL   0.408253  0.397423  0.216092  0.188206    ...    -0.005148
# PCTWEB    0.079477  0.138055  0.030399  0.013606    ...     0.004613
# PERCDR   -0.058934 -0.073336 -0.031393 -0.031239    ...          NaN
# PERCSR    0.123030  0.154527  0.062509  0.040872    ...    -0.536666
# PERCDW    0.120368  0.075233  0.063532  0.075783    ...    -0.245306
# PERCSW   -0.123963 -0.108547 -0.062493 -0.047523    ...    -0.426053
# PERCDE   -0.004227 -0.009584 -0.001705  0.000827    ...    -0.322653
# PERCEX    0.135017  0.089212  0.082559  0.087780    ...    -0.275156
# TOTLCOMP  0.116408  0.114708  0.077651  0.063898    ...    -0.015659
# TOTWCOMP  0.138891  0.119341  0.072658  0.062371    ...    -0.014552
# TOTPCOMM -0.044032 -0.030177  0.007730 -0.021289    ...     0.023296
# FACEBOOK -0.153698 -0.138094 -0.064607 -0.072857    ...     0.162299
#
#             PERCSR    PERCDW    PERCSW    PERCDE    PERCEX  TOTLCOMP  \
# AGE       0.094689  0.088678 -0.100478 -0.014312  0.109337  0.105599
# SEX       0.005610  0.006305 -0.002653  0.001294  0.006400  0.002032
# EDUC     -0.008159  0.001824  0.003582  0.001768 -0.006638  0.106542
# INCOME    0.110663  0.106584 -0.115206 -0.007902  0.137107  0.133814
# KIDHOME  -0.088950 -0.073766  0.080994  0.013125 -0.100116 -0.091494
# TEENHOME -0.050395 -0.058333  0.052619  0.011207 -0.065858 -0.056391
# GOURMAGS  0.123030  0.120368 -0.123963 -0.004227  0.135017  0.116408
# WINEMAGS  0.154527  0.075233 -0.108547 -0.009584  0.089212  0.114708
# STYLMAGS  0.062509  0.063532 -0.062493 -0.001705  0.082559  0.077651
# HOUSMAGS  0.040872  0.075783 -0.047523  0.000827  0.087780  0.063898
# SPRTMAGS  0.018960  0.066684 -0.046737  0.006044  0.070476  0.032878
# TRAVMAGS  0.053916  0.053417 -0.060366 -0.009403  0.053243  0.094823
# CULTMAGS  0.010139  0.016746 -0.021149 -0.009287  0.018765  0.069532
# COMPMAGS  0.002808  0.000479 -0.008603 -0.006483  0.003941  0.007621
# FIRSTPUR -0.005492 -0.001804  0.000139 -0.000390 -0.009545  0.133341
# LASTPUR  -0.144757 -0.061951  0.093224  0.012136 -0.108297 -0.115096
# NPURCH    0.142828  0.065022 -0.105861 -0.010733  0.093929  0.300709
# TBOTTLES  0.125304  0.064901 -0.096230 -0.009553  0.089970  0.281209
# TOTCAT   -0.005342 -0.001661 -0.000659 -0.000258 -0.009431  0.133452
# TOTCREV   0.132386  0.069741 -0.107896 -0.011227  0.094377  0.273272
# TOTCCOST  0.137489  0.062145 -0.109074 -0.011708  0.087840  0.284464
# TOTCPROF  0.089323  0.090583 -0.085414 -0.007371  0.106744  0.181585
# REV1STYR  0.124201  0.069305 -0.109593 -0.011267  0.094890  0.198938
# REVLSTYR  0.148025  0.077943 -0.121009 -0.013260  0.107314  0.243736
# COSTLAST  0.153472  0.069785 -0.122550 -0.014174  0.100102  0.255804
# LTV       0.101323  0.093189 -0.092912 -0.007397  0.113065  0.169847
# PROBSTAY  0.097071  0.044790 -0.070662 -0.007931  0.067048  0.181262
# AVGPURCH  0.169458  0.131084 -0.220848 -0.020878  0.152795  0.156545
# AVGDISC  -0.022778 -0.234491  0.179164 -0.007916 -0.239279 -0.073115
# AVGQUAL   0.294785  0.104496 -0.366455 -0.030537  0.177046  0.113727
# PCTWEB   -0.000394 -0.007258 -0.000477 -0.001643 -0.001428  0.043849
# PERCDR   -0.536666 -0.245306 -0.426053 -0.322653 -0.275156 -0.015659
# PERCSR         NaN -0.087625 -0.218284 -0.132309  0.127066  0.036676
# PERCDW   -0.087625       NaN -0.101633 -0.059105  0.192497  0.018957
# PERCSW   -0.218284 -0.101633       NaN -0.110936  0.065132 -0.029507
# PERCDE   -0.132309 -0.059105 -0.110936       NaN  0.090177 -0.001087
# PERCEX    0.127066  0.192497  0.065132  0.090177       NaN  0.019790
# TOTLCOMP  0.036676  0.018957 -0.029507 -0.001087  0.019790       NaN
# TOTWCOMP  0.043738  0.018826 -0.034730 -0.006827  0.032296  0.110289
# TOTPCOMM  0.001807 -0.022448 -0.015530 -0.007808 -0.019133  0.036818
# FACEBOOK -0.082148 -0.081510 -0.052867 -0.048520 -0.078968 -0.033225
#
#           TOTWCOMP  TOTPCOMM  FACEBOOK
# AGE       0.114501  0.041707 -0.115318
# SEX      -0.000674  0.008251  0.004810
# EDUC      0.100368 -0.013074  0.004056
# INCOME    0.142149  0.030944 -0.137645
# KIDHOME  -0.087854 -0.041996  0.110675
# TEENHOME -0.056513 -0.021100  0.075065
# GOURMAGS  0.138891 -0.044032 -0.153698
# WINEMAGS  0.119341 -0.030177 -0.138094
# STYLMAGS  0.072658  0.007730 -0.064607
# HOUSMAGS  0.062371 -0.021289 -0.072857
# SPRTMAGS  0.040804 -0.029686 -0.067550
# TRAVMAGS  0.103400  0.025504 -0.059105
# CULTMAGS  0.071957  0.007878 -0.023843
# COMPMAGS  0.025665 -0.002783 -0.005550
# FIRSTPUR  0.124506  0.128291  0.000069
# LASTPUR  -0.113651 -0.087414  0.088446
# NPURCH    0.301360  0.136515 -0.107573
# TBOTTLES  0.283593  0.091582 -0.103544
# TOTCAT    0.124485  0.128706  0.000957
# TOTCREV   0.276327  0.037855 -0.113881
# TOTCCOST  0.285777  0.071058 -0.107606
# TOTCPROF  0.191522 -0.108821 -0.121978
# REV1STYR  0.216240  0.014689 -0.112287
# REVLSTYR  0.251725  0.020449 -0.128970
# COSTLAST  0.263144  0.051048 -0.121481
# LTV       0.176019 -0.103329 -0.133055
# PROBSTAY  0.170292  0.160073 -0.065635
# AVGPURCH  0.160438 -0.035311 -0.206795
# AVGDISC  -0.077502  0.061278  0.160615
# AVGQUAL   0.111809  0.013118 -0.035234
# PCTWEB    0.046899 -0.007221 -0.002110
# PERCDR   -0.014552  0.023296  0.162299
# PERCSR    0.043738  0.001807 -0.082148
# PERCDW    0.018826 -0.022448 -0.081510
# PERCSW   -0.034730 -0.015530 -0.052867
# PERCDE   -0.006827 -0.007808 -0.048520
# PERCEX    0.032296 -0.019133 -0.078968
# TOTLCOMP  0.110289  0.036818 -0.033225
# TOTWCOMP       NaN  0.031919 -0.035462
# TOTPCOMM  0.031919       NaN  0.134732
# FACEBOOK -0.035462  0.134732       NaN
#
# [41 rows x 41 columns]

# %%
for column in corr.columns:
    print(column, corr[column].max())
# Out:
# ('CUSTID', 0.015946771099111374)
# ('AGE', 0.71089979036539142)
# ('AGEGRP1', 0.071807003763905169)
# ('AGEGRP2', 0.46032555132893938)
# ('AGEGRP3', 0.39160481270662262)
# ('AGEGRP4', 0.19351752061846086)
# ('AGEGRP5', 0.36208645844158166)
# ('AGEGRP6', 0.69187483283043771)
# ('SEX', 0.43596587644947765)
# ('EDUC', 0.47755133769366165)
# ('INCOME', 0.79284778499548181)
# ('INCGRP1', 0.08791983613111469)
# ('INCGRP2', 0.46032555132893938)
# ('INCGRP3', 0.17461744141881402)
# ('INCGRP4', 0.084590477643812972)
# ('INCGRP5', 0.17578750037256149)
# ('INCGRP6', 0.79284778499548181)
# ('KIDHOME', 0.44556162839251423)
# ('TEENHOME', 0.35807402127772125)
# ('GOURMAGS', 0.5755663541030962)
# ('WINEMAGS', 0.50289759928980771)
# ('STYLMAGS', 0.58544041588393714)
# ('HOUSMAGS', 0.58544041588393714)
# ('SPRTMAGS', 0.27296260293959329)
# ('TRAVMAGS', 0.42614206522796738)
# ('CULTMAGS', 0.47755133769366165)
# ('COMPMAGS', 0.34922757052109193)
# ('FIRSTPUR', 0.99805967521013161)
# ('LASTPUR', 0.3216766762034024)
# ('NPURCH', 0.94584656749503593)
# ('TBOTTLES', 0.9886467521089557)
# ('TOTCAT', 0.99805967521013161)
# ('TOTCREV', 0.9930571399327166)
# ('TOTCCOST', 0.9930571399327166)
# ('TOTCPROF', 0.93130938545260233)
# ('REV1STYR', 0.81047420786653979)
# ('REVLSTYR', 0.99269122871698268)
# ('COSTLAST', 0.99269122871698268)
# ('LTV', 0.93130938545260233)
# ('PROBSTAY', 0.61311913992952116)
# ('AVGPURCH', 0.68920931425788801)
# ('AVGDISC', 0.33549155104748707)
# ('AVGQUAL', 0.68586925780600294)
# ('PCTWEB', 0.38763889602664203)
# ('PERCDR', 0.16229901553155843)
# ('PERCSR', 0.29478524092932995)
# ('PERCDW', 0.19249739358103002)
# ('PERCSW', 0.1791641942744453)
# ('PERCDE', 0.090176848020656869)
# ('PERCEX', 0.19249739358103002)
# ('TOTLCOMP', 0.3007091435747285)
# ('TOTWCOMP', 0.30135964448810182)
# ('TOTPCOMM', 0.16007340492507191)
# ('FACEBOOK', 0.16229901553155843)
# ('WINETAST', 0.48826558564659722)

# %%
corr.to_csv('corr.csv')

# %%
predicted1 = model.predict(x1)
predictedAcceptRate1 = predicted1.mean()
precision1 = metrics.precision_score(y1, predicted1)

print(predictedAcceptRate1)
print(precision1)
print(calculate_profit(model, x1, y1))
# Out:
# 0.1771
# 0.427442123094
# 347218.4

# %%
predicted2 = model.predict(x2)
predictedAcceptRate2 = predicted2.mean()
precision2 = metrics.precision_score(y2, predicted2)

print(predictedAcceptRate2)
print(precision2)
print(calculate_profit(model, x2, y2))
# Out:
# 0.184618461846
# 0.42091007584
# 354536.253625
